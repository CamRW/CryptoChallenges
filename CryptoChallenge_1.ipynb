# %%
import convert_hex_to_base64 as h2b

# %%
x = '49276d206b696c6c696e6720796f757220627261696e206c696b65206120706f69736f6e6f7573206d757368726f6f6d'
s = 'SSdtIGtpbGxpbmcgeW91ciBicmFpbiBsaWtlIGEgcG9pc29ub3VzIG11c2hyb29t'

# %%
from importlib import reload

# %%
reload(h2b)
# Out:
# <module 'convert_hex_to_base64' from '/Users/cameronweigel/Desktop/convert_hex_to_base64.py'>

# %%
y = h2b.hex_to_base64(x)

# %%
print (y)

# %%
q = '234124'
q_test = h2b.hex_to_base64(q)

# %%
from bitstring import BitArray
str_1 = BitArray(hex='1c0111001f010100061a024b53535009181c')
str_2 = BitArray(hex='686974207468652062756c6c277320657965')

res = h2b.fixed_xor(str_1,str_2)
print (res)
# Out:
# 0x746865206b696420646f6e277420706c6179

# %%
print (h2b.fixed_xor(str_1,str_2))

# %%
hex = '1b37373331363f78151b7f2b783431333d78397828372d363c78373e783a393b3736'
print(h2b.xor_cipher_break(hex))
# Out:
# Cooking MC's like a pound of bacon

# %%
lines = [line.rstrip('\n') for line in open('/Users/cameronweigel/4.txt')]

# %%
print (lines)
# Out:
# ['0e3647e8592d35514a081243582536ed3de6734059001e3f535ce6271032', '334b041de124f73c18011a50e608097ac308ecee501337ec3e100854201d', '40e127f51c10031d0133590b1e490f3514e05a54143d08222c2a4071e351', '45440b171d5c1b21342e021c3a0eee7373215c4024f0eb733cf006e2040c', '22015e420b07ef21164d5935e82338452f42282c1836e42536284c450de3', '043b452e0268e7eb005a080b360f0642e6e342005217ef04a42f3e43113d', '581e0829214202063d70030845e5301f5a5212ed0818e22f120b211b171b', 'ea0b342957394717132307133f143a1357e9ed1f5023034147465c052616', '0c300b355c2051373a051851ee154a023723414c023a08171e1b4f17595e', '550c3e13e80246320b0bec09362542243be42d1d5d060e203e1a0c66ef48', 'e159464a582a6a0c50471310084f6b1703221d2e7a54502b2b205c433afa', 'ec58ea200e3005090e1725005739eda7342aed311001383fff7c58ef1f11', '01305424231c0d2c41f105057f74510d335440332f1038ec17275f5814e1', '05f12f380720ea2b19e24a07e53c142128354e2827f25a08fb401c3126a6', '0d17272f53063954163d050a541b1f1144305ae37d4932431b1f33140b1b', '0b4f070f071fe92c200e1fa05e4b272e50201b5d493110e429482c100730', '100a3148080f227fe60a132f0c10174fe3f63d1a5d38eb414ca8e82f2b05', '0a19e83c58400a023b13234572e6e4272bf67434331631e63b5e0f00175c', '54520c2ceb45530e0f78111d0b0707e01e4bf43b0606073854324421e6f9', '09e7585353ee4a34190de1354e481c373a1b2b0a136127383e271212191f', '0f060d09fb4f2d5024022c5ff6463c390c2b5f1a5532071a31f33503fcea', '371d39121605584f48217235ee1e0602445c162e4942254c071954321d29', '4a0900e63e5f161e15554045f3594c2a6a77e4e52711602beaf53ae53bed', '29011616565d2a372a605bee39eced31183fe068185c3b445b391fe53232', 'e4102337000303452a1e2f2b29493f54ed5a037b3e08311b625cfd005009', '2d560d4b0618203249312a310d5f541f295c3f0f25235c2b20037d1600f3', '2c245155e8253708391a7ceb0d05005c3e080f3f0f0e5a16583b111f4448', '493804044d262eec3759594f212d562420105d6a39e70a0f3957f347070c', 'e72d1d1f103807590f4339575e00381074485d2d580249f744052605e11d', 'e131570ae95307143a71131729552d001057a4540a1f425b190b572dee34', '2c1655342f02581c202b0a5c17a358291e1506f325550f05365e165c1c5f', 'e318164df80b043e5406296e5359271d152f552e155a43eda81f23231d1c', '001de0413e174e18192c061e4b3d1b5626f90e3e1429544a20ee150d0c20', '32e902193219033c58191302441a5c1b584825ea140c290927aaea53e23c', '3a36363a732e32ea3f0e430508204b332c382a19292d5b291122e123446a', '1804115614031f5f571f2b143c5d3c1b257a4b37350f18445a3e08341c3d', '21f2fb250b2e55151e77253a3f0e5f4b2030370a4155e720e73914e35a4a', '510a55583a3c491221397c123a2b14a8305b3b09e71b241d0e51202e1a32', '1b51202f4917232b512a141d6812f03c455df05e5a1c2cee14390b3b593a', '5f5731e5203116ee131a4a4b24112cef5d0822f035e6547d3a0014462f26', '0028fb522104f771501a555d3f581e30e9ec3e49e3e63123432f07794145', '1459f6312f000e5a1373e346e40f211e1b0b0e17000f391f170552150500', '7e301e18325717e3412e022f087be30e5641080151357714e0e0eee15e11', '533258e9360f513b083aa51d2824222f40200a470537ecec392d31070b38', '07e32c180dfa56496a461627542115132a4c284050495b23e2245b093159', '2d3c230a1e5a300f6c3e26ed0d1709434950fd6f1e121335054129e4e4ec', 'ef22fa2112311b11584ce43434f46f521a215433f9514fe33d313a3e0838', '34e7f336270c08010f2f544f0f1c1e235c0222644c2632efec061de2115f', '121a42395d4c560d213b0c0a26a7e4f4382718153d5e511158a10b2c021e', 'e05d414dfa40222f0c382a03235f4d0d04372d4b7855105e26e44f2e0555', '7f3a4f1351f85b0344223e1177e14707190c0e311f4ca633f5f3e9352372', '01424d5d1a322a0d381717130e181d07240c2c19ecee750b1a37085d014c', '16012c5de55a0314a8260e2759e439123ca0c81c321d454e4e0ee14f4c1d', '0b1415512f38580e4e2a227def242643183c224f0ea146443403022fe9fd', '43eb2b1078322a02192d5b5e0c360d584d0b5e2c13072912ee32f03f4155', '002a52553e08361b0be0074b573e201c164c093a5c0f0159333b59770d5b', '38e63c1c5244301a5a01f26930321256143e1ae05e1120a9eaf20a192d58', '7d54140a152ef4035f09083ded531ee04df55848020656a1342e502649eb', '0c211dfe101702015516341136252f3f06f73247133113f5642d083a3417', '015e3d51433f3c003e5e28030b1d413eee186824504b241e0f0d32373e2b', '2d465040ec130c5c0e2704aa17010c40095207223669110f22f45ea155f7', '14552e2b341e5ce0195351066a23e3283e0ee935444b255a1c5c3cef7614', '372b453d5a357c05142be65b3c17f9 ...

# %%
cipher = []
for line in lines:
     cipher.append(h2b.xor_cipher_break(line))

# %%
for list in cipher:
    print (list + '\n')
# Out:
# )EJð1$
#
# 5
#
#  G|pc}aS9k~)oUt:4t]hBLJ 1
#
# XDNHrg}QOi]½  rw£¸ o£U±W_
#
# @c< ieCt/;WAZ'M JNzTGTJ.'o
#
#  a
# &LÃÏ$~,/+"fÂÇf$v3Ë g5
#
# p6 	j*.X+ mÍ7rz:Å 0Ê:#	3?3
#
# Ù8d
# t$ 4 '	 dÚÞ,c0rtuo6%
#
# }AzD-Q FKti d;sFR0=sKyfoj>f(/
#
# È1q*"6 JÃd
#
# )6:(Z| 7c`x?gsRm^
# $ [[P,3J
#
#  XvH}qvo]x/AßLRIhy@G gi
#
# uD PWhyX5qq%yG 4G[dLcS+,`
#
#  Í>Åm Â3iÕ}/Üg;
#
# /0
#
# ,h ( 8Î)8yl	w<zn7Ão7
#
# Ûq|Ø5
#
# Ü^<Ìt%*=v
#
# su+Ìbt)(_6:,  Ç9lÓ!! scÁÞ
#
# z+  9Gj~F=;oDIhXy`TKMTaajl
#
# pyrv0R/[}S 9CFsT e*MxeNJ|
#
#
# Ó#;?ya+tq:$i
#
# ÌÅ#ûÓÛÐ6ï¯²! âÔ¥î/0ÿ þ(
#
# rm)Ó
#
# Ç3#  f	=
# jwÎy X+8AÞ#s*
#
# .P;-Þ
#
#  2TÃ%-(t ''&r>p97l`
#
# m  i
# È}}k	r4yNÃ.+s×c#(
#
# ê 5
# ì
#
# F }$pcMd`^"Zwg Ó#}h5,n| ZC
#
#  c4n*<j!n(#0Åc93h j*i
#
# Þ%+pÅ69i;Snd (h(g~Ð" !
#
# þ_ 	P2U#H8ç
# 7JT>ð>
#
# Ð;  :a *;}#e"aqÓ-50ÓjÛ
#
#  ,, i4(ð%Y:Q)6"037A38û9^p
#
# 7 |b0$
#
# $÷þ +Pr ?:ZN%52DPâ%â<æ_O
#
# cKZeÙA*JxjUl Q_kC
#
# j Q^8fRZ [elcM4,/+m]eHzJ(K
#
# NF ô1 ÿ[Z5=þL3á$÷El+W>7
#
# Ûr$×Qp:u}x>ÉÌiÃÆc'Yae
#
# 4yÖ .z3SÃfÄ/>;+.7 /?7%r5%
#
# ½óÝÛñÔ íÁìË¸ ÍËÂö´×##-"Ò
#
# þ%úÃ÷ÄöiÑäèîãìÆÉû  õáýËÇô
#
# nEqd? /N=H|zC%A)9 2JM2`X0
#
# 4 d1RÓ3)7}wnÃQ ,-;ÚÚÒ
#
# î#û 0YMå55õnS U2øPNâ<0;?	9
#
# Kc	ÀÃ)2Í>p
#
#  (po~d?	>8ÖÆ
# *'lc#j90,
#
# 0, -OBaUGnN2 `iZ@&8}3K"Ch8
#
#  eL§\}aN(¾XFSQn@ùlª¬¶j|-
#
# 8ÍÏT*;)| m
#
#  	wÊ<æ23k`` Ïab3
#
#  æò
#
# Qù9j 8?IL$J_L>;ü â-SG
#
# R$BG-%GiE
#
# (ö,BT
# Jây "F.
# ðN0¹úâ	=H
#
# X¯: ^(Gå
#
#
#
# @#O]!" @6_ ðv:NU:,) 5
#
# M&0 sl<nGdÊwal i2gBV	qoB>Á5
#
#  a*hÔ-ge2^×
# ÛB
#
# < N6Q>w íP7ò& CX2: ò!XZ6
#
#  .P):z2|VDY/l7FB_]GTpÖm3L'[W
#
# d $ag+\ Ef^XLShÚN^Gh(i#vl
#
# 8)åU#A/DQ >?^
#
# % ñ/:];#þYC¿'-0Q I#AB
#
# eP z>vFAf&4~njB 7S!n8(`g
#
# V	# Aq`B*QW÷A©RYãY M
#
# TZ2 KG
#
# ëì^_?~  \K3Y&.'Á?
#  G+l:
#
# (a =nF2a#s#H6tBF"0
#
# ;3õ4X=|V(/27í &NZh	U o
#
# r28 $"Ïy4 t(z.c6%k1:xRi{
#
# gImxrMWni +`0:cF8V/ 5aNh1N
#
#  9åCH$±÷
#
#  XprHxE"_l[N} ZPtS|EZ%,>s
#
#  ?~1m{9 u?%Ùf0l'/Ý}u#%'
#
#
# 5  4|$Ëvh"$c	i#2ip4`2p
#
# pFW Zc;@_~/8{  7xc%h[&/j`My
#
# îp§´¼ · ½ÎuÞØÌª¿q ëØ¥ÏÛ`
#
# gCY=XK`*i XKgLU3-
#
#  `9Æ4>z|d/r*"Ñe 58{
#
# gV tW]hNÕ#CuMS'( $"Xrvx<@Uj
#
# =+_]V, JQr0K[ðù *)F<R7Xá
#
# 'B4äý%=O,=5÷, >S'
#
# ^ "\?#!ùôV80 04DD;2#é
#
# $KûG
#
# i|O3 K]!una.=)-"STum o_[h
#
# &&I8ü>]9Né3 Fj
#
#  ~:ÊÔ;k)(%-={7gØm*>lÑiÀ
#
# ÃÂ Ü!%y|.<-=jYoxk$Çu!=h$ 2
#
#  l%D:
# 3u?&9Ù5wj 5Ø-×Æd}6y
#
# 9õW%¬í Rü4YS¡B6PQ^U
#
# fD/tOar+Tjn_4 .E2, ueH
#
# iZ%4H2ø)÷M E~Eåæ7 UDJ(?v:Q[
#
#  Ì2
# 'mha
#
# 1tÈkxrßd Ð"5
#
# GN=8 txnO3^}'.@pye_`xV m51TZ
#
# 4= `+'oaØ 4p6 (yebÔ!8
#
# n36Ú| /m"T+:4?, 2s;Àr
#
# G + "([
# w"VI5©#-
#
# VD p | <N \XpC@?hPB(c9_X P
#
# GQ* H
# +4;#M ã%^è+&§æ4
#
# äM Dæ#%ÿ4/#K-
#
#  k.{: Þ}h}6ÈoÖ~Ó+
#
# [AX mNizcLhW |@Lne5M'u`T`O
#
# 4 ûF 7; ,Z$þ8WEM#hO>ç
#
# T8
#
# /7â ÀÞÚëÚ)"ÝÛá'ÏÇáÑÁiöæÂ Ê
#
# 5 tcAz/4g=)ÍÜ 2 =1
#
# éÁÐÃáºç Þà -ïÑÇÒfÌóÙå
#
# Z=H1wo g]ck
#
#  }%4lyI?ojo}) ts~LÞ´"IK75
#
# r{u12 37jS`jD~=nED a)<~CUKb&
#
#  %v8 uj6.~m<ÒvkÛ9:#
#
# },1Ý${w Ù.*>k	 hhcj;c7
#
# bSY* -'tZdv|Wusm! dhl6zLP"
#
# h%RWf  Axlo1?Td'!DT#*(u3O?
#
# ÿ\[ð?F -'  %2/XEHôY fG-=
# >
#
# îQ
# í:* W(PU&,
#
# :} u-h -&VGVUl3Y[]y{QSr>OQ
#
# )xrB^4(C *R.N7$ ÜP@Ð9$MY
#
# ' 8Ö"j6i0t?b53:Á#g1kld
#
# 8Ø$p9z(Í)u 2uÑ5@.t3+Ø  }Í
#
# ca'Lb BtzÇf\?5;^_S {gj
#
# },ÏÜp8?`	g
#
# v`~$?)%  'wÉÏup5u/2
#
# ' u{X,r0e#\Na{=<H,3kc  c2Ze
#
# u: |xÈ!*2u#5>& l/m Ì54f
#
# b g0
#
# @ DJö>4 :_G8Ym>V:6O17ýN
#
# u 6{ ÆyÉ!:">Î<C4&878)
#
# 'å >Y8" RVbR$C0_SDz_öB#]Yè8ª
#
#  , (
# >B#[LPvã%2
#
# ³U Oc\|T( JTmL}	a8zwHVA&P0Fe
#
# ' v2{Ä--Í84,m" iuh
#
#  '6AM=^D%YzXnm pa8UUXr"G*DZ
#
# vxvt0+.b 4Ì5)Lt>ÄÖ,
#
# ( í÷^
# A)CM ;þ:¹5NMú$zY!
#
# ìIA
#
# p}0 \m>9 nay.c3|5e(tÛ(x
#
#  ÛÄ-ñÈ×þ Ó/ã×ÆËüØÔÝÁúïýÒ
#
# ;!< §] LY"RY^0
# ê
#
# Õ sv2ct/:(3}8
#
# Gc 3g,Ì*30uÖ1Ñ~=Ö) Jr8-8C
#
# >O	7#2<; **{# Ê
#
# c81Kã &ÜÅ  &%=ÐHÁt<3oZ0ÕuÌ
#
# çÚÏËÞæá Ó&ó§åñÉñãÖÑúÕ$, `
#
# I0 [Rg*HME7_-m+]@ DqZC@lRew$
#
# 2D áò<óA _OG%@êH.cH"65
#
#
#
#  5=ë39øî<.(XO1#û(I g;:
#
#  Úx:k1e+Õ~}[81(96hÄci +
#
# Ø$"u&t
#
# *N
#
# 4 qE@^< ZeZn=VSJt1Wcui
#
# @ie zVZ~=h6 AYXH ;6#}xX?U$nr
#
#  í°ðýíOEâ¿Bø&(W1
#
# R î²AB.WG8ê_ø&ê'Qÿ83 5*D
#
# %"q '0M;7cBÙ# 	k]3=5?Ðj
#
# 5?@ð< 5}ì1L*T/
#
#  B 95ME:>EX®2-B' ]H
#
# {ZI~ xX,-eC$cN24 H_<x hF%
#
# ut
#
# <q:~` =)u3"Op9uvErv6,;s
#
# 7Ó(uÄ ;p z|q 6Î 1n8Ó
#
# M=4UVàK*R IH7
#
# DvG N#  Cq5]LztrJzZbkD@Õ
#
# 2|oLr£E scgu*,oc|= E1n]
#
# Now that the party is jumping
#
#
# #Ôo11Ò >6m
#
# >*MD Jûìè  ù
# I.ô)
#
#  No!Az4VN0_LiE9 {&Kqk.vnWiv
#
#  3#'(5]G ;YRçH:H@E!_*,
#
# Y@RSF:W	JüNUJ °K
#
# 0-NQ@!  }{=&_Vsy`~_pb/uha;#
#
# ø
#
# ù;&Z(%&0B;N'N:
#
# @ 2G$W "+<?÷'A$q.TB
#
#  ëêÅÑ¿çÙÙÅÎ(¬ï ðÔýÞôöîÉÇ
#
# ×,;d În	g87|f  '#=ÑT#8
#
#  aÑs|"5Ú:9 ?1{ß,vbCjÛÞfcØsf
#
# $<J=3B^v# ".P L>à@N î
#
# :Á}4byt ;
# 9'0k3)*É
# ÇeÏ=
#
# Ø$ ÛÅ<>u"< ?:dhb8*xÌ0
#
#  L3BM §!3.)1+'A'NU<*Râ*S
#
# 2hG/ buE"KiTqbcN9CdOOR W#
#
#  ?Ë;{ ÔvÓ5`)-ux3m=-×6rÑ}
#
# gÐk&"
#
# K *#EaÄ ,(4zfÛÓ0:8OÜj0).Î+
#
# 5 6[O :vLL.Cð>Uí[&QÛB
#
# áÈ ?Ù'Ç î0îÉÏÎÜ
#
# 	$Î?Z:Ù×/f
#  rXßz ÆÐÛ,
#
# È'54d!u 6:rq~ :gam|lÂh>
#
#  E+ W-$
# &0@L6S\.4)
#
# 17;ËQ Ú|q
#
#
# k7-prv8!/Ø4  l$1	*:1:
#
# &
#
# <0 è®
#
# y
#
# 't<Â +1e*v"1 }zr}Í>
#
# õ: Móþ)\159Të.**ùåê< üEZ
#
#  ^8H:T<>!/2OQÿZSIDFø#)Aå
#
#  |R>!cn2,m4MBz ~U&Y#q)=6B%
#
# _	 GU?+ %A/éU=1XÈLú
#
#  ?)ê%[/ûW=ån
#
# hqf!À; ;$Esv'Ð 8&Jm, {
#
#  t9g ~w+ÒÎ %
#
# )
# Ò8× Ú14g1 ÔDjÝ kË
#
# +#mvÚß -:$Js2t,&Ý7× <D
# >
#
# SX-?	ìW __æå),F64 YNQ÷Q
#
#  Kãþ
#
# ,ÂÓ 26~>?W>/(:z/; |Ë.
#
# Î m7Ìa00MÂ:b#d=`þ
#
# )"z.x("v%ÁÀ!/+#( Ó]$
#
# Â8|qz
#
# \x9M egdlm%yZOI,eI z?:.)"P
#
# 4x}h8 .%Í0!;{wÄrry's>
#
# mVVo @HZs*&SlØ¾: dpdOA` 4Us
#
# ^'?éH ú JK((2©!R4
#
#
# +Y4_7 ðBg $L÷0*Jøã,'é|)X]
#
# o=d%N96M{Rpg[ÄOEH; w] n1_Z`
#
#  w[mE-@:Çq3)! K'WS@*VPvW)c
#
#
#
#  F,:Y)E =-$[JFQQ) A>5
#
# !%l~xÃ 3
# ÓÀ:h
# a
#
# 4Ø ?+ *fÆg#j$-k9w?
#
# íÓ'ÑËøßØlÄ éÀ ÿîÈÁèÅÚiÖÀ
#
# /É
#
# $# (4== sk1~2ay);(9m+&
#
# 1=dz ?
#
# OFã "-,VVD"@ ';*ü"[. 'S!
#
# ï Y ]3î#9&=úB>Z5IR[S
#
# Bc> <Hk8/Z8!PR&À}? 2~;Y;yYHk
#
# %°óN5RL O8Q3+_ú
#
# [s5!"Nd2?Jk~
#
#  Òûáé°þâ ÎêãÑÇbÞÞö)Ü+ñí(
#
# ÁÙ
# Çs/sDwr t$l(
#
# R#o &{sy 3Vy`sD)+6$pK;nÊhZQN-
#
# 3-o qÓ :h,;S+Ç~
#
# WG6ä3Y ë!hì%æ
# /] CîT>]R&
#
# Ñ
#  `4d0$ /Ê*Ï)(ÛY	vÎ×:/|6
#
#  QNop'I Y1b ;'/"c#Rt^6a!`asp
#
# D X~ZC#P"#Ûy>] xs-) 'j7V/|
#
# ! ß"ñÅÑÉðçî, à+øîÊèÆÆÉ¸
#
#  Ï=Î:"t1 r:
# /*~/fgo,l`
#
# ,?F1 /²5'\*9|*
# <3^
# TJ.
#
# 2,W| jQ!rvGG- l )G8JQze
#
# C6óãî;X:j>J9ø%U -¾2KN Lì_
#
#
# A YOê.¾6õ^Cû ¿I#L 3B)&
#
# L 1ø,^RûN2 ¹òVA<V)
#
#  üQé[è,;K__($ õV P<X%A'4
#
# 9I
#
#  É~?Åd>)$n[Ôu)j;oRwo|
#
# $ i|<?-
#
#  ëÄÛð&ýæÙïÏÎòìçäùý:òßÍ ê
#
# # EC_P9I<ò^> *2Fù=?>îê^UK
#
# 9 0W'TI(CYEELK-ô5'p V
#
# % ;s6Æ0
#
# 4r&I[\`3Í'2] GMg .~p7F8vtv
#
# ;Á" flÚj0*(4$}Öz i:O
#
# 7
# 5 ^í0[a-	?S8 FO2V*#RV
#
# VZK ?, }ýMöXí#
#
# soQkYD tJP(f Ibdbz\<M>ÒVx114
#
#  Ë ÌÓd.a.}4m(ad%?6 ttU
#
# Î, lv-ÁÏ `$	h>#Ð{è}npÇ1
#
#  ! "/a;29f|s?<#Ñ203Ð
#
# ~h+ Ê<k6Ãgf : qÈÏ16q4
#
#  7
# +V{5ûJ2,/IC]	 R0+A?_5
#
# &aO 3@NÛQ7ElAF! ,nMh]4XbY8T
#
# 7Bþ?3PK:;Pü:!9Z D
#
# 4U :8)ôV'5(T9IK³ üD0IM17
#
# @cV^O D?2d[itU'dZ|jh; ~.pt|_
#
# 	ôð   åóL;NA!'!-åõ'TñO*0
#
# 2:. #{&  <|j6XÝ+l	&É/1
#
# gÂyi&-@h Äc'+,$$ c#Ð
#
#
#
# gf|b1i 8(8À u( Ëx
#
# F T>(T [)w?wdaB5EW!@;\#u$4Z|
#
#  >h
# (Ân42<5
#
# 9' U<-eSKZ0*G5trWM%d4|=
#
# 0J(Eí -9IZ@ö8þ *2:ê]Có#;<TF
#
# 6 tJxYT 4e}@KsWa<mtOEAL)
#
# ) /y=ñ
# 3 2O
#
# 1@0ú WB16Cÿ#)Y@ % z>
#
#  	@úø@!Ntý 1J3BG_ôó	-X%D
#
# 	%bJ9qj
#
#  A 9!üX$õGHQE?/ >.X½87H#
#
# -d"0 (13n 39)/c9<F 13
#
# 9- 6Îr8iß;m _$/l/u>,tj
#
# &>
#
# îã÷ Ô9èËÂÞéÃêèõáçï ßq5Õ
#
#  -?$u+y *)n/fg7#nw2ØOHi
#
#  Uã+Y3 ­Uä+i1O3O6p\
#
# _ HvHm?lw@fr%1$n KeAbC9:vO@h9W
#
# L  5E5ZFòIñBûó]Ò30E^+C>
#
# IgVOs|;%r- n' :bWYYL<(i}@q
#
# )yi L +À;"vk9@Ó2#
#
# 81ÅÖ+ vÁ?c
# n×/*<0z%v
#
# 2 5`ykÈ Þb:76Ï}fÛk\O#Ä1
#
# ÚÛÅ+d
# -l:)!v
#
# > ç-+Vo-æ(%*?7 1&ñSYIQ
#
# .ÒÜ m'*@0pk
#
# P	{=
#
# Rk C GkI0
# lN!twQ:5 DG`ÅIË?)
#
#  A; @ù<.êDñMB\ä_<þý>"
#
# l4,2	'pg =uÕ .wi1o o>p
# r21
#
# )ä+R æW6X=.ùú Pÿ(þøòü
#
# Ð ñÏÚÙÎÕþò öþÜ3õÍõÀÛÀûÁ3é
#
# ;Lî	 ·K!-0$-a
#
# r6:` @7Â{fr~j5sgbfy % Ây'+
#
# \ÏsÀ
#
# !lr 7H($= 1O6iZLKdH"+DEb
#
# PnÁ4.'960dÕ3Ä 7re& sÛ{!`Å
#
# $Q 9O'õ+60W&U4 	!¤
#
# ô!AQ)
# ïî
#
# ÀÈzo n)~1 lÔÛ/)uh8a8t>-'Q&
#
# Y Ag+"&JU!J+](\ ~.mZS5G<5fd
#
#  ES~]g-eW,)iqi{9?0b}ng\b oy#
#
# ñ
#
# 0Ä
#
# /@B!óà$I <, 'AJ2O.MF 5
#
#  ,7ù!mFF"1ì OáY3ný]*
#
#  d^=>7 k5fIwaAjG('kO[]Y(Km
#
#  kv;Yy|P0?8jSLuXefBTq7I9
#
# #JO Hlu8á$fS'*"7 B%<TV

# %%
reload(h2b)
data = ('Burning \'em, if you ain\'t quick and nimble\n'
         'I go crazy when I hear a cymbal')
key = 'ICE'
h2b.repeating_key_xor(key, data)
# Out:
# '0b3637272a2b2e63622c2e69692a23693a2a3c6324202d623d63343c2a26226324272765272a282b2f20430a652e2c652a3124333a653e2b2027630c692b20283165286326302e27'

# %%
reload(h2b)
h2b.break_repeating_key_xor()
# Out:
# range(2, 40)

# %%
from bitstring import BitArray
test_1 = "this is a test"
test_2 = "wokka wokka!!!"

a = ''.join(format(ord(x), 'b') for x in test_1)
b = ''.join(format(ord(y), 'b') for y in test_2)

print(format(ord(''), 'b'))
# Out:
# 100001

# %%
print ((a),'\n\n' ,(b), '\n', len(a) , '\n' ,len(b))
# Out:
# 11101001101000110100111100111000001101001111001110000011000011000001110100110010111100111110100
#
#  1110111110111111010111101011110000110000011101111101111110101111010111100001100001100001100001
#  95
#  94

# %%
reload(h2b)
print (h2b.edit_dist(test_1,test_2))
# Out:
# 37

# %%
import sys
KEYSIZE = 3
s = 'hammy whammy'
a =[]
b =[]
c =[]

    
for x in range(0,2*KEYSIZE, KEYSIZE):
    b.append(''.join(s[x:x+KEYSIZE]))
print(b)

for i in range(0,len(b)-1):
    c.append(h2b.edit_dist(b[i],b[i+1]))
print(c)
#for n in range(0, len(a)-1):
#if KEYSIZE > len(a) -> error: 'number of bytes in string less 
#''.join(ct_split[i::KEYSIZE] for i in range(KEYSIZE))
x = ((b[1]))
print(type(x))
# Out:
# ['ham', 'my ']
# [8]
# <class 'str'> 3

# %%
reload(h2b)
text = [line.strip() for line in open('/Users/cameronweigel/6.txt')]
text = (''.join(text))
text = h2b.base64_to_hex(text)
print(h2b.break_repeating_key_xor(text))
# Out:
# 0a1" 11% $`!D770c a$ q6  3t
# Ue±¼Vk'KÓ«.  [áôòÃã­<Ä
# u5 ep1q5 v %210 4Eq11cap5
# uF³gØ WõX¿þ:ãÈXh Æ¯Þ0µ5
# 00  e``B40Ef% 55p$%3aQ !1Q
# Ý?Åð¶eVwJê,;A³õr`-  ¨R
# eA%`D"5 b%&11!5!' du!u 0$
# 1~ ²
# !DcDq "  5 0f%dt`aq$Pb0%d@p
#  ÍuÐ¿ßÇåLËöifº»8VÕ%M L
# «
# None

# %%
x = ['aet', 'aeer']
y = 'agf'

x[x[0].join(y[1])
print(x)
# Out:
# ['aet', 'aeer']
